# %%
import pandas as pd
pd.set_option('display.width', 320)
colunas = ['preg', 'gluc', 'bloo', 'skin', 'insu', 'bmi', 'diab', 'age', 'outc']
dados = pd.read_csv('dados/pima-indians-diabetes.csv', names = colunas)
print(dados.corr(method = 'pearson'))
# Out:
#           preg      gluc      bloo      skin      insu       bmi      diab       age      outc
# preg  1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523  0.544341  0.221898
# gluc  0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337  0.263514  0.466581
# bloo  0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265  0.239528  0.065068
# skin -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928 -0.113970  0.074752
# insu -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071 -0.042163  0.130548
# bmi   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647  0.036242  0.292695
# diab -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000  0.033561  0.173844
# age   0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561  1.000000  0.238356
# outc  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844  0.238356  1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
colunas = ['preg', 'gluc', 'bloo', 'skin', 'insu', 'bmi', 'diab', 'age', 'outc']
dados = pd.read_csv('dados/pima-indians-diabetes.csv', names = colunas)
plt.figure(figsize=(10,10))
sns.heatmap(dados.corr())
plt.show()
